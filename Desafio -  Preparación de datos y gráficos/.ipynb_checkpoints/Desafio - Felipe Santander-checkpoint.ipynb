# %% [markdown]
# ![image.png](attachment:41d367d2-4754-4a7b-8f81-9d4344994d3d.png)

# %% [markdown]
# # **<font color="green">Desafío- Preparación de datos y gráficos</font>**

# %% [markdown]
#  Descripción
#  La base de datos world-data-2023.csv proporciona una gran cantidad de información sobre
#  todos los países del mundo, abarcando una amplia gama de indicadores y atributos. Incluye
#  estadísticas demográficas, indicadores económicos, factores ambientales, métricas de
#  atención médica, estadísticas educativas y mucho más. Con la representación de cada país,
#  este conjunto de datos ofrece una perspectiva global completa sobre diversos aspectos de
#  las naciones, lo que permite análisis en profundidad y comparaciones entre países. Las
#  variables consideradas son:
#
# **0.Country**: Nombre del país.
# 1. **Density (P/Km2)**: Densidad de población medida en personas por kilómetro cuadrado.
# 2. **Abbreviation**: Abreviatura o código que representa el país.
# 3. **Agricultural Land (%)**: Porcentaje del área de tierra utilizada para fines agrícolas.
# 4. **LandArea(Km2)**:Área total de tierra del país en kilómetros cuadrados.
# 5. **ArmedForcesSize**: Tamaño de las fuerzas armadas en el país.
# 6. **Birth Rate**: Número de nacimientos por 1,000 habitantes por año.
# 7. **Calling Code**: Código de llamada internacional para el país.
# 8. **Capital/Major City**: Nombre de la capital o ciudad principal.
# 9. **CO2Emissions**: Emisiones de dióxido de carbono en toneladas.
# 10. **CPI**: Índice de Precios al Consumidor, una medida de la inflación y el poder adquisitivo.
# 11. **CPI Change (%)**: Cambio porcentual en el Índice de Precios al Consumidor en comparación con el año anterior.
# 12. **Currency_Code**: Código de moneda utilizado en el país.
# 13. **Fertility Rate**: Número promedio de hijos nacidos de una mujer durante su vida.
# 14. **Forested Area (%)**: Porcentaje del área de tierra cubierta por bosques.
# 15. **Gasoline_Price**: Precio de la gasolina por litro en moneda local.
# 16. **GDP**: Producto Interno Bruto, el valor total de bienes y servicios producidos en el país.
# 17. **Gross Primary Education Enrollment (%)**: Tasa de inscripción bruta en educación primaria.
# 18. **Gross Tertiary Education Enrollment (%)**: Tasa de inscripción bruta en educación terciaria.
# 19. **Infant Mortality**: Número de muertes por cada 1,000 nacidos vivos antes de cumplir un año de edad.
# 20. **Largest City**: Nombre de la ciudad más grande del país.
# 21. **Life Expectancy**: Número promedio de años que se espera que viva un recién nacido.
# 22. **Maternal Mortality Ratio**: Número de muertes maternas por cada 100,000 nacidos vivos.
# 23. **MinimumWage**:Niveldesalario mínimo en moneda local.
# 24. **OfficialLanguage**: Idioma(s) oficial(es) hablado(s) en el país.
# 25. **Out of Pocket Health Expenditure (%)**: Porcentaje del gasto total en salud pagado directamente por los individuos.
# 26. **Physicians per Thousand**: Número de médicos por cada mil personas.
# 27. **Population**: Población total del país.
# 28. **Labor Force Participation (%)**: Porcentaje de la población que forma parte de la fuerza laboral.
# 29. **TaxRevenue(%)**: Ingresos fiscales como porcentaje del PIB.
# 30. **Total Tax Rate**: Carga tributaria total como porcentaje de las ganancias comerciales.
# 31. **UnemploymentRate**: Porcentaje de la fuerza laboral que está desempleada.
# 32. **UrbanPopulation**: Porcentaje de la población que vive en áreas urbanas.
# 33. **Latitude**: Coordenada de latitud de la ubicación del país.
# 34. **Longitude**: Coordenada de longitud de la ubicación del país.

# %% [markdown]
# ## **<font color="orange">Importación libreria</font>**

# %%
# libreria manipulacion de datos
import numpy as np
import pandas as pd 

# Libreria graficas
# Importar el módulo pyplot con el alias plt
import matplotlib.pyplot as plt
import seaborn as sns

# Para ver las graficas directamente en este notebook:
# %matplotlib inline


# Configuración warnings
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_columns = 100

# %% [markdown]
# ## **<font color="orange">Importación de datos</font>**

# %%
import_data = pd.read_csv('world-data-2023.csv')
import_data
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
import_data.shape
# Out:
# (195, 35)

# %%
import_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %% [markdown]
# ## **<font color="orange">Limpieza de datos</font>**
# Se efectuará la eliminación de las columnas para la creación del DataFrame = **'DF'**:
# - 'Abbreviation'
# - 'Calling Code'
# - 'Capital/Major City'
# - 'Currency-Code'
# - 'Largest city'
# - 'Official language'
# - 'Latitude', 'Longitude'
#
# Y se reemplazarán las variables de las columnas no númericas

# %%
df = import_data.drop(columns=['Abbreviation', 'Calling Code', 'Capital/Major City', 'Currency-Code', 'Largest city', 'Official language', 'Latitude', 'Longitude'])
df
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
#visualización de datos numericos
columns_numeric = df.select_dtypes(include=['float'])
columns_numeric
# Out:
#      Birth Rate  Fertility Rate  Infant mortality  Life expectancy  \
# 0         32.49            4.47              47.9             64.5
# 1         11.78            1.62               7.8             78.5
# 2         24.28            3.02              20.1             76.7
# 3          7.20            1.27               2.7              NaN
# 4         40.73            5.52              51.6             60.8
# ..          ...             ...               ...              ...
# 190       17.88            2.27              21.4             72.1
# 191       16.75            2.05              16.5             75.3
# 192       30.45            3.79              42.9             66.1
# 193       36.19            4.63              40.4             63.5
# 194       30.68            3.62              33.9             61.2
#
#      Maternal mortality ratio  Physicians per thousand
# 0                       638.0                     0.28
# ...

# %%
columns_object = df.select_dtypes(include=['object'])
columns_object
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
#reemplazo de caracteres para transformación de datos a numericos
for i in columns_object.drop('Country', axis=1).columns:
    df[i] = df[i].apply(lambda x: float(str(x)\
            .replace('%','')\
            .replace('$','')\
            .replace(',','')))

# %%
df.head(15)
# Out:
#                 Country  Density\n(P/Km2)  Agricultural Land( %)  \
# 0           Afghanistan              60.0                   58.1
# 1               Albania             105.0                   43.1
# 2               Algeria              18.0                   17.4
# 3               Andorra             164.0                   40.0
# 4                Angola              26.0                   47.5
# 5   Antigua and Barbuda             223.0                   20.5
# 6             Argentina              17.0                   54.3
# 7               Armenia             104.0                   58.9
# 8             Australia               3.0                   48.2
# 9               Austria             109.0                   32.4
# 10           Azerbaijan             123.0                   57.7
# 11          The Bahamas              39.0                    1.4
# 12              Bahrain            2239.0                   11.1
# ...

# %% [markdown]
# ## **<font color="orange">Comienzo del desafio:</font>**
# ### Vamos a realizar algunos análisis comparativos entre las variables. Para ello:
# 1. *Carga los datos y genera un dataFrame que excluya las columnas correspondientes  a la abreviatura del país, código de llamada, capital, código de moneda, ciudad más grande, lenguaje oficial, latitud y longitud. Considerando estos datos, realiza una inspección inicial sobre ellos, considerando gráficos. Concluye.*

# %%
#limpieza de dataframe listo:
df
# Out:
#          Country  Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 0    Afghanistan              60.0                   58.1        652230.0
# 1        Albania             105.0                   43.1         28748.0
# 2        Algeria              18.0                   17.4       2381741.0
# 3        Andorra             164.0                   40.0           468.0
# 4         Angola              26.0                   47.5       1246700.0
# ..           ...               ...                    ...             ...
# 190    Venezuela              32.0                   24.5        912050.0
# 191      Vietnam             314.0                   39.3        331210.0
# 192        Yemen              56.0                   44.6        527968.0
# 193       Zambia              25.0                   32.1        752618.0
# 194     Zimbabwe              38.0                   41.9        390757.0
#
#      Armed Forces size  Birth Rate  Co2-Emissions      CPI  CPI Change (%)  \
# ...

# %%
#dataframe 'df', ahora limpio podemos aplicar describe:
df.describe()
# Out:
#        Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# count        195.000000             188.000000    1.940000e+02
# mean         356.764103              39.117553    6.896244e+05
# std         1982.888967              21.783052    1.921609e+06
# min            2.000000               0.600000    0.000000e+00
# 25%           35.500000              21.700000    2.382825e+04
# 50%           89.000000              39.600000    1.195110e+05
# 75%          216.500000              55.375000    5.242560e+05
# max        26337.000000              82.600000    1.709824e+07
#
#        Armed Forces size  Birth Rate  Co2-Emissions          CPI  \
# count       1.710000e+02  189.000000   1.880000e+02   178.000000
# mean        1.592749e+05   20.214974   1.777992e+05   190.460955
# std         3.806288e+05    9.945774   8.387903e+05   397.947380
# min         0.000000e+00    5.900000   1.100000e+01    99.030000
# 25%         1.100000e+04   11.300000   2.304250e+03   113.885000
# ...

# %%
#datos faltantes, podemos observar que la columna 'Minimum wage' presenta la mayor  cantidad de ausencia de datos:
missing_values = df.apply(lambda x: sum(x.isnull()),axis=0)
missing_values
# Out:
# Country                                       0
# Density\n(P/Km2)                              0
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# Out of pocket health expenditure              7
# ...

# %%
df.hist(figsize=(20, 15), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se evidenicia preliminarmente que los datos presentan altos datos átipicos entre cada columna que se vaya visualizando, los cuales pueden afectar en la calidad del análisis, se requiere evaluar cada una y realizar reemplazos de ser necesarios.

# %% [markdown]
# *2. De las variables codificadas numéricamente, ¿hay pares de ellas en la que parezca
#  haber correlación? ¿Para cuál(es) de ellas se observa más claramente?. Elige 2 pares
#  de variables.*

# %%
df_numerico = df.drop(columns=['Country'])

#calcular la matriz de correlaciones
correlation_matrix = df_numerico.corr()

# Mostrar el mapa de calor
plt.figure(figsize=(18, 15))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Matriz de correlaciones')
plt.show()

# %%
sns.regplot(x=df['Out of pocket health expenditure'],
            y=df['CPI'], 
            color= "gray", 
            marker= '.',
            scatter_kws = {"alpha":0.4}, line_kws  = {"color":"g","alpha":0.7})

plt.title('Out of pocket health expenditure vs CPI')
plt.xlabel('Out of pocket health expenditure')
plt.ylabel('CPI')
plt.show()

# %%
sns.regplot(x=df['Tax revenue (%)'],
            y=df['Urban_population'], 
            color= "gray", 
            marker= '.',
            scatter_kws = {"alpha":0.4}, line_kws  = {"color":"y","alpha":0.7})

plt.title('Tax revenue (%) vs Urban population')
plt.xlabel('Tax Revenue (%)')
plt.ylabel('Urban_population')
plt.show()

# %% [markdown]
# *3. Considera los dos pares de variables anteriores y elimina en cada caso los faltantes
#  y atípicos. Justifica en cada caso tu procedimiento.*

# %%
#para trabajar con las variables que escogí, realice un nuevo dataframe llamado 'df2':
df2 =df[['Country', 'Out of pocket health expenditure', 'CPI','Tax revenue (%)', 'Urban_population']]
df2
# Out:
#          Country  Out of pocket health expenditure      CPI  Tax revenue (%)  \
# 0    Afghanistan                              78.4   149.90              9.3
# 1        Albania                              56.9   119.05             18.6
# 2        Algeria                              28.1   151.36             37.2
# 3        Andorra                              36.4      NaN              NaN
# 4         Angola                              33.4   261.73              9.2
# ..           ...                               ...      ...              ...
# 190    Venezuela                              45.8  2740.27              NaN
# 191      Vietnam                              43.5   163.52             19.1
# 192        Yemen                              81.0   157.58              NaN
# 193       Zambia                              27.5   212.31             16.2
# 194     Zimbabwe                              25.8   105.51             20.7
#
#      Urban_population
# ...

# %%
#visualizaremos la cantidad de datos faltantes:
missing_values_df2 = df2.apply(lambda x: sum(x.isnull()),axis=0)
missing_values_df2
# Out:
# Country                              0
# Out of pocket health expenditure     7
# CPI                                 17
# Tax revenue (%)                     26
# Urban_population                     5
# dtype: int64

# %% [markdown]
# Para la visualización de los datos, primeramente realizaré una limpieza de aquellos  valores NaN, para eso, los actualizaré columna a columna por el promedio de los datos.
# Esto con el obejtivo de no elimnar datos ya que Tax renueve(%) esta dentro de un rango significativo.

# %%
df2['Out of pocket health expenditure'].fillna(df['Out of pocket health expenditure'].mean(), inplace=True)
df2
# Out:
#          Country  Out of pocket health expenditure      CPI  Tax revenue (%)  \
# 0    Afghanistan                              78.4   149.90              9.3
# 1        Albania                              56.9   119.05             18.6
# 2        Algeria                              28.1   151.36             37.2
# 3        Andorra                              36.4      NaN              NaN
# 4         Angola                              33.4   261.73              9.2
# ..           ...                               ...      ...              ...
# 190    Venezuela                              45.8  2740.27              NaN
# 191      Vietnam                              43.5   163.52             19.1
# 192        Yemen                              81.0   157.58              NaN
# 193       Zambia                              27.5   212.31             16.2
# 194     Zimbabwe                              25.8   105.51             20.7
#
#      Urban_population
# ...

# %%
df2['CPI'].fillna(df['CPI'].mean(), inplace=True)
df2
# Out:
#          Country  Out of pocket health expenditure          CPI  \
# 0    Afghanistan                              78.4   149.900000
# 1        Albania                              56.9   119.050000
# 2        Algeria                              28.1   151.360000
# 3        Andorra                              36.4   190.460955
# 4         Angola                              33.4   261.730000
# ..           ...                               ...          ...
# 190    Venezuela                              45.8  2740.270000
# 191      Vietnam                              43.5   163.520000
# 192        Yemen                              81.0   157.580000
# 193       Zambia                              27.5   212.310000
# 194     Zimbabwe                              25.8   105.510000
#
#      Tax revenue (%)  Urban_population
# 0                9.3         9797273.0
# 1               18.6         1747593.0
# 2               37.2        31510100.0
# ...

# %%
df2['Tax revenue (%)'].fillna(df['Tax revenue (%)'].mean(), inplace=True)
df2
# Out:
#          Country  Out of pocket health expenditure          CPI  \
# 0    Afghanistan                              78.4   149.900000
# 1        Albania                              56.9   119.050000
# 2        Algeria                              28.1   151.360000
# 3        Andorra                              36.4   190.460955
# 4         Angola                              33.4   261.730000
# ..           ...                               ...          ...
# 190    Venezuela                              45.8  2740.270000
# 191      Vietnam                              43.5   163.520000
# 192        Yemen                              81.0   157.580000
# 193       Zambia                              27.5   212.310000
# 194     Zimbabwe                              25.8   105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# 1          18.600000         1747593.0
# 2          37.200000        31510100.0
# ...

# %%
df2['Urban_population'].fillna(df['Urban_population'].mean(), inplace=True)
df2
# Out:
#          Country  Out of pocket health expenditure          CPI  \
# 0    Afghanistan                              78.4   149.900000
# 1        Albania                              56.9   119.050000
# 2        Algeria                              28.1   151.360000
# 3        Andorra                              36.4   190.460955
# 4         Angola                              33.4   261.730000
# ..           ...                               ...          ...
# 190    Venezuela                              45.8  2740.270000
# 191      Vietnam                              43.5   163.520000
# 192        Yemen                              81.0   157.580000
# 193       Zambia                              27.5   212.310000
# 194     Zimbabwe                              25.8   105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# 1          18.600000         1747593.0
# 2          37.200000        31510100.0
# ...

# %% [markdown]
# Ahora, para realizar la comparativa de los graficos, seleccionaré solo los datos no atípicos, utilizando como referencia el rango intercuartil, segun la siguiente formula:
# ```
# data = df['columna']
# Q1 = np.percentile(data, 25)
# Q3 = np.percentile(data, 75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# df=df.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
# ```

# %%
data = df2['Out of pocket health expenditure']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df2=df2.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
df2
# Out:
#          Country  Out of pocket health expenditure          CPI  \
# 0    Afghanistan                              78.4   149.900000
# 1        Albania                              56.9   119.050000
# 2        Algeria                              28.1   151.360000
# 3        Andorra                              36.4   190.460955
# 4         Angola                              33.4   261.730000
# ..           ...                               ...          ...
# 190    Venezuela                              45.8  2740.270000
# 191      Vietnam                              43.5   163.520000
# 192        Yemen                              81.0   157.580000
# 193       Zambia                              27.5   212.310000
# 194     Zimbabwe                              25.8   105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# 1          18.600000         1747593.0
# 2          37.200000        31510100.0
# ...

# %%
data = df2['CPI']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df2=df2.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
df2
# Out:
#          Country  Out of pocket health expenditure         CPI  \
# 0    Afghanistan                              78.4  149.900000
# 1        Albania                              56.9  119.050000
# 2        Algeria                              28.1  151.360000
# 3        Andorra                              36.4  190.460955
# 4         Angola                              33.4  261.730000
# ..           ...                               ...         ...
# 189      Vanuatu                               8.9  117.130000
# 191      Vietnam                              43.5  163.520000
# 192        Yemen                              81.0  157.580000
# 193       Zambia                              27.5  212.310000
# 194     Zimbabwe                              25.8  105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# 1          18.600000         1747593.0
# 2          37.200000        31510100.0
# 3          16.573964           67873.0
# ...

# %%
data = df2['Tax revenue (%)']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df2=df2.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
df2
# Out:
#                  Country  Out of pocket health expenditure         CPI  \
# 0            Afghanistan                              78.4  149.900000
# 1                Albania                              56.9  119.050000
# 3                Andorra                              36.4  190.460955
# 4                 Angola                              33.4  261.730000
# 5    Antigua and Barbuda                              24.3  113.810000
# ..                   ...                               ...         ...
# 189              Vanuatu                               8.9  117.130000
# 191              Vietnam                              43.5  163.520000
# 192                Yemen                              81.0  157.580000
# 193               Zambia                              27.5  212.310000
# 194             Zimbabwe                              25.8  105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# ...

# %%
data = df2['Urban_population']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df2=df2.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
df2
# Out:
#                  Country  Out of pocket health expenditure         CPI  \
# 0            Afghanistan                              78.4  149.900000
# 1                Albania                              56.9  119.050000
# 3                Andorra                              36.4  190.460955
# 5    Antigua and Barbuda                              24.3  113.810000
# 7                Armenia                              81.6  129.180000
# ..                   ...                               ...         ...
# 187              Uruguay                              16.2  202.920000
# 189              Vanuatu                               8.9  117.130000
# 192                Yemen                              81.0  157.580000
# 193               Zambia                              27.5  212.310000
# 194             Zimbabwe                              25.8  105.510000
#
#      Tax revenue (%)  Urban_population
# 0           9.300000         9797273.0
# ...

# %% [markdown]
# *4. Construye un gráfico para verificar la correlación entre estas variables, ahora con los
#  datos preparados. Compara con lo obtenido anteriormente.*

# %% [markdown]
# **Procedo con la visualización de los datos ya filtrados:**

# %%
sns.regplot(x=df2['Tax revenue (%)'],
            y=df2['Urban_population'], 
            color= "gray", 
            marker= '.',
            scatter_kws = {"alpha":0.4}, line_kws  = {"color":"y","alpha":0.7})

plt.title('Tax revenue (%) vs Urban population')
plt.xlabel('Tax Revenue (%)')
plt.ylabel('Urban_population')
plt.show()

# %% [markdown]
# Países altamente urbanizados como menos urbanizados pueden tener niveles variados de ingresos fiscales.

# %%
sns.regplot(x=df2['Out of pocket health expenditure'],
            y=df2['CPI'], 
            color= "gray", 
            marker= '.',
            scatter_kws = {"alpha":0.4}, line_kws  = {"color":"g","alpha":0.7})

plt.title('Out of pocket health expenditure vs CPI')
plt.xlabel('Out of pocket health expenditure')
plt.ylabel('CPI')
plt.show()

# %% [markdown]
# Grafico sugiere que el porcentaje de gasto privado en salud no está directamente asociado con la inflación general en un país.

# %% [markdown]
# *5. Realiza lo mismo para comparar la cantidad de médicos por cada mil personas y la
#  esperanza de vida. ¿Qué puedes concluir?*

# %%
#creación del dataframe 'df3'
df3 = df[['Country','Life expectancy', 'Physicians per thousand']]
df3
# Out:
#          Country  Life expectancy  Physicians per thousand
# 0    Afghanistan             64.5                     0.28
# 1        Albania             78.5                     1.20
# 2        Algeria             76.7                     1.72
# 3        Andorra              NaN                     3.33
# 4         Angola             60.8                     0.21
# ..           ...              ...                      ...
# 190    Venezuela             72.1                     1.92
# 191      Vietnam             75.3                     0.82
# 192        Yemen             66.1                     0.31
# 193       Zambia             63.5                     1.19
# 194     Zimbabwe             61.2                     0.21
#
# [195 rows x 3 columns]

# %%
#visualización de datos faltantes
missing_values_df3 = df3.apply(lambda x: sum(x.isnull()),axis=0)
missing_values_df3
# Out:
# Country                    0
# Life expectancy            8
# Physicians per thousand    7
# dtype: int64

# %%
#reemplazo por promedio
df3['Life expectancy'].fillna(df['Life expectancy'].mean(), inplace=True)
df3
# Out:
#          Country  Life expectancy  Physicians per thousand
# 0    Afghanistan        64.500000                     0.28
# 1        Albania        78.500000                     1.20
# 2        Algeria        76.700000                     1.72
# 3        Andorra        72.279679                     3.33
# 4         Angola        60.800000                     0.21
# ..           ...              ...                      ...
# 190    Venezuela        72.100000                     1.92
# 191      Vietnam        75.300000                     0.82
# 192        Yemen        66.100000                     0.31
# 193       Zambia        63.500000                     1.19
# 194     Zimbabwe        61.200000                     0.21
#
# [195 rows x 3 columns]

# %%
df3['Physicians per thousand'].fillna(df['Physicians per thousand'].mean(), inplace=True)
df3
# Out:
#          Country  Life expectancy  Physicians per thousand
# 0    Afghanistan        64.500000                     0.28
# 1        Albania        78.500000                     1.20
# 2        Algeria        76.700000                     1.72
# 3        Andorra        72.279679                     3.33
# 4         Angola        60.800000                     0.21
# ..           ...              ...                      ...
# 190    Venezuela        72.100000                     1.92
# 191      Vietnam        75.300000                     0.82
# 192        Yemen        66.100000                     0.31
# 193       Zambia        63.500000                     1.19
# 194     Zimbabwe        61.200000                     0.21
#
# [195 rows x 3 columns]

# %%
#visualización de atipicos - Physicians per thousand
sns.displot(x=df3['Life expectancy'], kde=True)
plt.show()

# %%
#visualización de atipicos - Life expectancy
sns.displot(x=df3['Physicians per thousand'], kde=True)
plt.show()

# %% [markdown]
# Dado a lo evaluado en los histogramas, no se visualizan datos atipicos

# %%
sns.regplot(x=df3['Physicians per thousand'],
            y=df3['Life expectancy'], 
            color= "blue", 
            marker= '.',
            scatter_kws = {"alpha":0.5}, line_kws  = {"color":"y","alpha":0.7})

plt.title('Physicians per thousand vs Life expectancy')
plt.xlabel('Physicians per thousand')
plt.ylabel('Life expectancy')
plt.show()

# %% [markdown]
# **conclusión**:
# Se evidencia que a mayor sea la  cantidad de medicos en por cada mil personas, es que la esperanza de vida va en aumento

# %% [markdown]
# *6. Construye un gráfico para representar la población total de los países y su producto
#  interno bruto. Prepara los datos y escoge el gráfico adecuado (si es necesario, limpia
#  y/o transforma los datos). Justifica.*

# %%
#creación de 'df4'
df4=df[['Country','Population','Tax revenue (%)']]
df4
# Out:
#          Country  Population  Tax revenue (%)
# 0    Afghanistan  38041754.0              9.3
# 1        Albania   2854191.0             18.6
# 2        Algeria  43053054.0             37.2
# 3        Andorra     77142.0              NaN
# 4         Angola  31825295.0              9.2
# ..           ...         ...              ...
# 190    Venezuela  28515829.0              NaN
# 191      Vietnam  96462106.0             19.1
# 192        Yemen  29161922.0              NaN
# 193       Zambia  17861030.0             16.2
# 194     Zimbabwe  14645468.0             20.7
#
# [195 rows x 3 columns]

# %%
#al tener pocos datos faltantes, agregue el promedio para rellenar
df4['Population'].fillna(df['Population'].mean(), inplace=True)

# %%
df4['Tax revenue (%)'].fillna(df['Tax revenue (%)'].mean(), inplace=True)

# %%
#Filtre entre los intercuartiles de población ya que este presentaba datos átipicos significativos
data = df4['Population']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df4=df4.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
df4
# Out:
#          Country  Population  Tax revenue (%)
# 0    Afghanistan  38041754.0         9.300000
# 1        Albania   2854191.0        18.600000
# 2        Algeria  43053054.0        37.200000
# 3        Andorra     77142.0        16.573964
# 4         Angola  31825295.0         9.200000
# ..           ...         ...              ...
# 189      Vanuatu    299882.0        17.800000
# 190    Venezuela  28515829.0        16.573964
# 192        Yemen  29161922.0        16.573964
# 193       Zambia  17861030.0        16.200000
# 194     Zimbabwe  14645468.0        20.700000
#
# [162 rows x 3 columns]

# %%
#visualización de datos atipicos
sns.boxplot(data = df4)
plt.show()

# %%
# datos numericos
plt.figure(figsize=(8,4))
#diagonal histogramas los demas son scatter plots

sns.pairplot(df4)
plt.show()

# %%
#grafico de dispersión
plt.figure(figsize=(10 ,20), dpi=100)
sns.lmplot(x='Population',y='Tax revenue (%)',data=df4)
plt.show()

# %% [markdown]
# Los puntos están muy dispersos y la línea de tendencia es prácticamente horizontal, lo que indica que el tamaño de la población no determina directamente la proporción de ingresos fiscales sobre el PIB.

# %% [markdown]
# *7. Escoge otro par de datos, limpialos, prepáralos y analiza su posible relación. Justifica
#  utilizando las herramientas vistas y gráficos adecuados.*
#
# **Unemployment Rate VS Labor Force Participation (%)**

# %%
#creación de 'df5' y eliminación de datos nulos:
df5 = df[['Country','Unemployment rate','Population: Labor force participation (%)']].dropna()
df5
# Out:
#          Country  Unemployment rate  Population: Labor force participation (%)
# 0    Afghanistan              11.12                                       48.9
# 1        Albania              12.33                                       55.7
# 2        Algeria              11.70                                       41.2
# 4         Angola               6.89                                       77.5
# 6      Argentina               9.79                                       61.3
# ..           ...                ...                                        ...
# 190    Venezuela               8.80                                       59.7
# 191      Vietnam               2.01                                       77.4
# 192        Yemen              12.91                                       38.0
# 193       Zambia              11.43                                       74.6
# 194     Zimbabwe               4.95                                       83.1
#
# [176 rows x 3 columns]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df5, 
                x='Unemployment rate', 
                y='Population: Labor force participation (%)')
plt.title('Tasa de Desempleo y Participación en la Fuerza Laboral')
plt.xlabel('Tasa de Desempleo (%)')
plt.ylabel('Participación en la Fuerza Laboral (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# Observamos que no existe una relación estrictamente lineal entre la tasa de desempleo y la participación en la fuerza laboral. Sin embargo, en general, países con muy baja participación laboral tienden a tener mayores tasas de desempleo.
